# %%
# !pip install tensorflow==1.14
# !pip install -U -q keras
# !pip install -U -q pandas
# !pip install -U -q numpy
# Out:
# Collecting tensorflow==1.14
#   Downloading https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (109.2MB)
#      |████████████████████████████████| 109.2MB 69kB/s
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.0.8)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.1.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.8.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.11.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.33.6)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.8.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.12.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.2.2)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.17.4)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (3.10.0)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 32.8MB/s
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 52.0MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.14) (41.6.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (0.16.0)
# Installing collected packages: tensorboard, tensorflow-estimator, tensorflow
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorflow 1.15.0
#     Uninstalling tensorflow-1.15.0:
#       Successfully uninstalled tensorflow-1.15.0
# Successfully installed tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0
#      |████████████████████████████████| 378kB 4.8MB/s

# %%
# Download the DataSet file from public google drive folder
# The direct download link was generated via https://www.gdirect.link/

# https://stackoverflow.com/a/49576950/289970
import os
import urllib.request
urllib.request.urlretrieve('https://drive.google.com/uc?export=download&id=1s6MbI8_Dw9jBp7LLwWycvfs_-kOqisET', 'DataSet.zip')
# !ls
# Out:
# DataSet.zip  sample_data

# %%
# Unzip the dataset and remove the zip file
# !unzip DataSet.zip
# !rm DataSet.zip
# Out:
# Archive:  DataSet.zip
#    creating: DataSet/
#   inflating: DataSet/.DS_Store
#   inflating: __MACOSX/DataSet/._.DS_Store
#   inflating: DataSet/class_labels_indices.csv
#    creating: DataSet/train/
#    creating: DataSet/val/
#   inflating: DataSet/train/3b.tfrecord
#   inflating: __MACOSX/DataSet/train/._3b.tfrecord
#   inflating: DataSet/train/3C.tfrecord
#   inflating: __MACOSX/DataSet/train/._3C.tfrecord
#   inflating: DataSet/train/4e.tfrecord
#   inflating: __MACOSX/DataSet/train/._4e.tfrecord
#   inflating: DataSet/train/4D.tfrecord
#   inflating: __MACOSX/DataSet/train/._4D.tfrecord
#   inflating: DataSet/train/0_.tfrecord
#   inflating: __MACOSX/DataSet/train/._0_.tfrecord
#   inflating: DataSet/train/2Q.tfrecord
#   inflating: __MACOSX/DataSet/train/._2Q.tfrecord
#   inflating: DataSet/train/2p.tfrecord
#   inflating: __MACOSX/DataSet/train/._2p.tfrecord
#   inflating: DataSet/train/0L.tfrecord
#   inflating: __MACOSX/DataSet/train/._0L.tfrecord
#   inflating: DataSet/train/0M.tfrecord
#   inflating: __MACOSX/DataSet/train/._0M.tfrecord
#   inflating: DataSet/train/03.tfrecord
#   inflating: __MACOSX/DataSet/train/._03.tfrecord
#   inflating: DataSet/train/1U.tfrecord
#   inflating: __MACOSX/DataSet/train/._1U.tfrecord
#   inflating: DataSet/train/02.tfrecord
#   inflating: __MACOSX/DataSet/train/._02.tfrecord
#   inflating: DataSet/train/1T.tfrecord
#   inflating: __MACOSX/DataSet/train/._1T.tfrecord
#   inflating: DataSet/train/_V.tfrecord
#   inflating: __MACOSX/DataSet/train/.__V.tfrecord
#   inflating: DataSet/train/_W.tfrecord
#   inflating: __MACOSX/DataSet/train/.__W.tfrecord
#   inflating: DataSet/train/3H.tfrecord
#   inflating: __MACOSX/DataSet/train/._3H.tfrecord
#   inflating: DataSet/train/3i.tfrecord
#   inflating: __MACOSX/DataSet/train/._3i.tfrecord
#   inflating: DataSet/train/0F.tfrecord
#   inflating: __MACOSX/DataSet/train/._0F.tfrecord
#   inflating: DataSet/train/0g.tfrecord
#   inflating: __MACOSX/DataSet/train/._0g.tfrecord
#   inflating: DataSet/train/-V.tfrecord
#   inflating: __MACOSX/DataSet/train/._-V.tfrecord
#   inflating: DataSet/train/-W.tfrecord
#   inflating: __MACOSX/DataSet/train/._-W.tfrecord
#   inflating: DataSet/train/2Z.tfrecord
#   inflating: __MACOSX/DataSet/train/._2Z.tfrecord
#   inflating: DataSet/train/4o.tfrecord
#   inflating: __MACOSX/DataSet/train/._4o.tfrecord
#   inflating: DataSet/train/4n.tfrecord
#   inflating: __MACOSX/DataSet/train/._4n.tfrecord
#   inflating: DataSet/train/-H.tfrecord
#   inflating: __MACOSX/DataSet/train/._-H.tfrecord
#   inflating: DataSet/train/2e.tfrecord
#   inflating: __MACOSX/DataSet/train/._2e.tfrecord
#   inflating: DataSet/train/-I.tfrecord
#   inflating: __MACOSX/DataSet/train/._-I.tfrecord
#   inflating: DataSet/train/2d.tfrecord
#   inflating: __MACOSX/DataSet/train/._2d.tfrecord
#   inflating: DataSet/train/0x.tfrecord
#   inflating: __MACOSX/DataSet/train/._0x.tfrecord
#   inflating: DataSet/train/0y.tfrecord
#   inflating: __MACOSX/DataSet/train/._0y.tfrecord
#   inflating: DataSet/train/4q.tfrecord
#   inflating: __MACOSX/DataSet/train/._4q.tfrecord
#   inflating: DataSet/train/4p.tfrecord
#   inflating: __MACOSX/DataSet/train/._4p.tfrecord
#   inflating: DataSet/train/_H.tfrecord
#   inflating: __MACOSX/DataSet/train/.__H.tfrecord
#   inflating: DataSet/train/_I.tfrecord
#   inflating: __MACOSX/DataSet/train/.__I.tfrecord
#   inflating: DataSet/train/3v.tfrecord
#   inflating: __MACOSX/DataSet/train/._3v.tfrecord
#   inflating: DataSet/train/3w.tfrecord
#   inflating: __MACOSX/DataSet/train/._3w.tfrecord
#   inflating: DataSet/train/0-.tfrecord
#   inflating: __MACOSX/DataSet/train/._0-.tfrecord
#   inflating: DataSet/train/1K.tfrecord
#   inflating: __MACOSX/DataSet/train/._1K.tfrecord
#   inflating: DataSet/train/1j.tfrecord
#   inflating: __MACOSX/DataSet/train/._1j.tfrecord
#   inflating: DataSet/train/0R.tfrecord
#   inflating: __MACOSX/DataSet/train/._0R.tfrecord
#   inflating: DataSet/train/0S.tfrecord
#   inflating: __MACOSX/DataSet/train/._0S.tfrecord
#   inflating: DataSet/train/2o.tfrecord
#   inflating: __MACOSX/DataSet/train/._2o.tfrecord
#   inflating: DataSet/train/-b.tfrecord
#   inflating: __MACOSX/DataSet/train/._-b.tfrecord
#   inflating: DataSet/train/2N.tfrecord
#   inflating: __MACOSX/DataSet/train/._2N.tfrecord
#   inflating: DataSet/train/-C.tfrecord
#   inflating: __MACOSX/DataSet/train/._-C.tfrecord
#   inflating: DataSet/train/_7.tfrecord
#   inflating: __MACOSX/DataSet/train/.__7.tfrecord
#   inflating: DataSet/train/_6.tfrecord
#   inflating: __MACOSX/DataSet/train/.__6.tfrecord
#   inflating: DataSet/train/1A.tfrecord
#   inflating: __MACOSX/DataSet/train/._1A.tfrecord
#   inflating: DataSet/train/_b.tfrecord
#   inflating: __MACOSX/DataSet/train/.__b.tfrecord
#   inflating: DataSet/train/_c.tfrecord
#   inflating: __MACOSX/DataSet/train/.__c.tfrecord
#   inflating: DataSet/train/-7.tfrecord
#   inflating: __MACOSX/DataSet/train/._-7.tfrecord
#   inflating: DataSet/train/-6.tfrecord
#   inflating: __MACOSX/DataSet/train/._-6.tfrecord
#   inflating: DataSet/train/-O.tfrecord
#   inflating: __MACOSX/DataSet/train/._-O.tfrecord
#   inflating: DataSet/train/2B.tfrecord
#   inflating: __MACOSX/DataSet/train/._2B.tfrecord
#   inflating: DataSet/train/-n.tfrecord
#   inflating: __MACOSX/DataSet/train/._-n.tfrecord
#   inflating: DataSet/train/2C.tfrecord
#   inflating: __MACOSX/DataSet/train/._2C.tfrecord
#   inflating: DataSet/train/4V.tfrecord
#   inflating: __MACOSX/DataSet/train/._4V.tfrecord
#   inflating: DataSet/train/4W.tfrecord
#   inflating: __MACOSX/DataSet/train/._4W.tfrecord
#   inflating: DataSet/train/_O.tfrecord
#   inflating: __MACOSX/DataSet/train/.__O.tfrecord
#   inflating: DataSet/train/_n.tfrecord
#   inflating: __MACOSX/DataSet/train/.__n.tfrecord
#   inflating: DataSet/train/3q.tfrecord
#   inflating: __MACOSX/DataSet/train/._3q.tfrecord
#   inflating: DataSet/train/3P.tfrecord
#   inflating: __MACOSX/DataSet/train/._3P.tfrecord
#   inflating: DataSet/train/1L.tfrecord
#   inflating: __MACOSX/DataSet/train/._1L.tfrecord
#   inflating: DataSet/train/1m.tfrecord
#   inflating: __MACOSX/DataSet/train/._1m.tfrecord
#   inflating: DataSet/train/1_.tfrecord
#   inflating: __MACOSX/DataSet/train/._1_.tfrecord
#   inflating: DataSet/train/0U.tfrecord
#   inflating: __MACOSX/DataSet/train/._0U.tfrecord
#   inflating: DataSet/train/0T.tfrecord
#   inflating: __MACOSX/DataSet/train/._0T.tfrecord
#   inflating: DataSet/train/2h.tfrecord
#   inflating: __MACOSX/DataSet/train/._2h.tfrecord
#   inflating: DataSet/train/-e.tfrecord
#   inflating: __MACOSX/DataSet/train/._-e.tfrecord
#   inflating: DataSet/train/2i.tfrecord
#   inflating: __MACOSX/DataSet/train/._2i.tfrecord
#   inflating: DataSet/train/-D.tfrecord
#   inflating: __MACOSX/DataSet/train/._-D.tfrecord
#   inflating: DataSet/train/_0.tfrecord
#   inflating: __MACOSX/DataSet/train/.__0.tfrecord
#   inflating: DataSet/train/_1.tfrecord
#   inflating: __MACOSX/DataSet/train/.__1.tfrecord
#   inflating: DataSet/train/1f.tfrecord
#   inflating: __MACOSX/DataSet/train/._1f.tfrecord
#   inflating: DataSet/train/1g.tfrecord
#   inflating: __MACOSX/DataSet/train/._1g.tfrecord
#   inflating: DataSet/train/_e.tfrecord
#   inflating: __MACOSX/DataSet/train/.__e.tfrecord
#   inflating: DataSet/train/_D.tfrecord
#   inflating: __MACOSX/DataSet/train/.__D.tfrecord
#   inflating: DataSet/train/-0.tfrecord
#   inflating: __MACOSX/DataSet/train/._-0.tfrecord
#   inflating: DataSet/train/-1.tfrecord
#   inflating: __MACOSX/DataSet/train/._-1.tfrecord
#   inflating: DataSet/train/3z.tfrecord
#   inflating: __MACOSX/DataSet/train/._3z.tfrecord
#   inflating: DataSet/train/_Z.tfrecord
#   inflating: __MACOSX/DataSet/train/.__Z.tfrecord
#   inflating: DataSet/train/3e.tfrecord
#   inflating: __MACOSX/DataSet/train/._3e.tfrecord
#   inflating: DataSet/train/3D.tfrecord
#   inflating: __MACOSX/DataSet/train/._3D.tfrecord
#   inflating: DataSet/train/1x.tfrecord
#   inflating: __MACOSX/DataSet/train/._1x.tfrecord
#   inflating: DataSet/train/1y.tfrecord
#   inflating: __MACOSX/DataSet/train/._1y.tfrecord
#   inflating: DataSet/train/4b.tfrecord
#   inflating: __MACOSX/DataSet/train/._4b.tfrecord
#   inflating: DataSet/train/4C.tfrecord
#   inflating: __MACOSX/DataSet/train/._4C.tfrecord
#   inflating: DataSet/train/2V.tfrecord
#   inflating: __MACOSX/DataSet/train/._2V.tfrecord
#   inflating: DataSet/train/2w.tfrecord
#   inflating: __MACOSX/DataSet/train/._2w.tfrecord
#   inflating: DataSet/train/-z.tfrecord
#   inflating: __MACOSX/DataSet/train/._-z.tfrecord
#   inflating: DataSet/train/1-.tfrecord
#   inflating: __MACOSX/DataSet/train/._1-.tfrecord
#   inflating: DataSet/train/0k.tfrecord
#   inflating: __MACOSX/DataSet/train/._0k.tfrecord
#   inflating: DataSet/train/0J.tfrecord
#   inflating: __MACOSX/DataSet/train/._0J.tfrecord
#   inflating: DataSet/train/04.tfrecord
#   inflating: __MACOSX/DataSet/train/._04.tfrecord
#   inflating: DataSet/train/1R.tfrecord
#   inflating: __MACOSX/DataSet/train/._1R.tfrecord
#   inflating: DataSet/train/1S.tfrecord
#   inflating: __MACOSX/DataSet/train/._1S.tfrecord
#   inflating: DataSet/train/_q.tfrecord
#   inflating: __MACOSX/DataSet/train/.__q.tfrecord
#   inflating: DataSet/train/_p.tfrecord
#   inflating: __MACOSX/DataSet/train/.__p.tfrecord
#   inflating: DataSet/train/3O.tfrecord
#   inflating: __MACOSX/DataSet/train/._3O.tfrecord
#   inflating: DataSet/train/3N.tfrecord
#   inflating: __MACOSX/DataSet/train/._3N.tfrecord
#   inflating: DataSet/train/0A.tfrecord
#   inflating: __MACOSX/DataSet/train/._0A.tfrecord
#   inflating: DataSet/train/-q.tfrecord
#   inflating: __MACOSX/DataSet/train/._-q.tfrecord
#   inflating: DataSet/train/-P.tfrecord
#   inflating: __MACOSX/DataSet/train/._-P.tfrecord
#   inflating: DataSet/train/4H.tfrecord
#   inflating: __MACOSX/DataSet/train/._4H.tfrecord
#   inflating: DataSet/train/4I.tfrecord
#   inflating: __MACOSX/DataSet/train/._4I.tfrecord
#   inflating: DataSet/train/4x.tfrecord
#   inflating: __MACOSX/DataSet/train/._4x.tfrecord
#   inflating: DataSet/train/2_.tfrecord
#   inflating: __MACOSX/DataSet/train/._2_.tfrecord
#   inflating: DataSet/train/-a.tfrecord
#   inflating: __MACOSX/DataSet/train/._-a.tfrecord
#   inflating: DataSet/train/2L.tfrecord
#   inflating: __MACOSX/DataSet/train/._2L.tfrecord
#   inflating: DataSet/train/2M.tfrecord
#   inflating: __MACOSX/DataSet/train/._2M.tfrecord
#   inflating: DataSet/train/_4.tfrecord
#   inflating: __MACOSX/DataSet/train/.__4.tfrecord
#   inflating: DataSet/train/_5.tfrecord
#   inflating: __MACOSX/DataSet/train/.__5.tfrecord
#   inflating: DataSet/train/0Q.tfrecord
#   inflating: __MACOSX/DataSet/train/._0Q.tfrecord
#   inflating: DataSet/train/0P.tfrecord
#   inflating: __MACOSX/DataSet/train/._0P.tfrecord
#   inflating: DataSet/train/4-.tfrecord
#   inflating: __MACOSX/DataSet/train/._4-.tfrecord
#   inflating: DataSet/train/_a.tfrecord
#   inflating: __MACOSX/DataSet/train/.__a.tfrecord
#   inflating: DataSet/train/-4.tfrecord
#   inflating: __MACOSX/DataSet/train/._-4.tfrecord
#   inflating: DataSet/train/-5.tfrecord
#   inflating: __MACOSX/DataSet/train/._-5.tfrecord
#   inflating: DataSet/train/1B.tfrecord
#   inflating: __MACOSX/DataSet/train/._1B.tfrecord
#   inflating: DataSet/train/1C.tfrecord
#   inflating: __MACOSX/DataSet/train/._1C.tfrecord
#   inflating: DataSet/train/0Z.tfrecord
#   inflating: __MACOSX/DataSet/train/._0Z.tfrecord
#   inflating: DataSet/train/2f.tfrecord
#   inflating: __MACOSX/DataSet/train/._2f.tfrecord
#   inflating: DataSet/train/-k.tfrecord
#   inflating: __MACOSX/DataSet/train/._-k.tfrecord
#   inflating: DataSet/train/2g.tfrecord
#   inflating: __MACOSX/DataSet/train/._2g.tfrecord
#   inflating: DataSet/train/-J.tfrecord
#   inflating: __MACOSX/DataSet/train/._-J.tfrecord
#   inflating: DataSet/train/4r.tfrecord
#   inflating: __MACOSX/DataSet/train/._4r.tfrecord
#   inflating: DataSet/train/4S.tfrecord
#   inflating: __MACOSX/DataSet/train/._4S.tfrecord
#   inflating: DataSet/train/1H.tfrecord
#   inflating: __MACOSX/DataSet/train/._1H.tfrecord
#   inflating: DataSet/train/1i.tfrecord
#   inflating: __MACOSX/DataSet/train/._1i.tfrecord
#   inflating: DataSet/train/_k.tfrecord
#   inflating: __MACOSX/DataSet/train/.__k.tfrecord
#   inflating: DataSet/train/_j.tfrecord
#   inflating: __MACOSX/DataSet/train/.__j.tfrecord
#   inflating: DataSet/train/3u.tfrecord
#   inflating: __MACOSX/DataSet/train/._3u.tfrecord
#   inflating: DataSet/train/3T.tfrecord
#   inflating: __MACOSX/DataSet/train/._3T.tfrecord
#   inflating: DataSet/train/_u.tfrecord
#   inflating: __MACOSX/DataSet/train/.__u.tfrecord
#   inflating: DataSet/train/_T.tfrecord
#   inflating: __MACOSX/DataSet/train/.__T.tfrecord
#   inflating: DataSet/train/3k.tfrecord
#   inflating: __MACOSX/DataSet/train/._3k.tfrecord
#   inflating: DataSet/train/2-.tfrecord
#   inflating: __MACOSX/DataSet/train/._2-.tfrecord
#   inflating: DataSet/train/3J.tfrecord
#   inflating: __MACOSX/DataSet/train/._3J.tfrecord
#   inflating: DataSet/train/1v.tfrecord
#   inflating: __MACOSX/DataSet/train/._1v.tfrecord
#   inflating: DataSet/train/00.tfrecord
#   inflating: __MACOSX/DataSet/train/._00.tfrecord
#   inflating: DataSet/train/1W.tfrecord
#   inflating: __MACOSX/DataSet/train/._1W.tfrecord
#   inflating: DataSet/train/01.tfrecord
#   inflating: __MACOSX/DataSet/train/._01.tfrecord
#   inflating: DataSet/train/4_.tfrecord
#   inflating: __MACOSX/DataSet/train/._4_.tfrecord
#   inflating: DataSet/train/2x.tfrecord
#   inflating: __MACOSX/DataSet/train/._2x.tfrecord
#   inflating: DataSet/train/-U.tfrecord
#   inflating: __MACOSX/DataSet/train/._-U.tfrecord
#   inflating: DataSet/train/2y.tfrecord
#   inflating: __MACOSX/DataSet/train/._2y.tfrecord
#   inflating: DataSet/train/-T.tfrecord
#   inflating: __MACOSX/DataSet/train/._-T.tfrecord
#   inflating: DataSet/train/0e.tfrecord
#   inflating: __MACOSX/DataSet/train/._0e.tfrecord
#   inflating: DataSet/train/0d.tfrecord
#   inflating: __MACOSX/DataSet/train/._0d.tfrecord
#   inflating: DataSet/train/4L.tfrecord
#   inflating: __MACOSX/DataSet/train/._4L.tfrecord
#   inflating: DataSet/train/4M.tfrecord
#   inflating: __MACOSX/DataSet/train/._4M.tfrecord
#   inflating: DataSet/train/3a.tfrecord
#   inflating: __MACOSX/DataSet/train/._3a.tfrecord
#   inflating: DataSet/train/4f.tfrecord
#   inflating: __MACOSX/DataSet/train/._4f.tfrecord
#   inflating: DataSet/train/4g.tfrecord
#   inflating: __MACOSX/DataSet/train/._4g.tfrecord
#   inflating: DataSet/train/0O.tfrecord
#   inflating: __MACOSX/DataSet/train/._0O.tfrecord
#   inflating: DataSet/train/0n.tfrecord
#   inflating: __MACOSX/DataSet/train/._0n.tfrecord
#   inflating: DataSet/train/2r.tfrecord
#   inflating: __MACOSX/DataSet/train/._2r.tfrecord
#   inflating: DataSet/train/2S.tfrecord
#   inflating: __MACOSX/DataSet/train/._2S.tfrecord
#   inflating: DataSet/train/_r.tfrecord
#   inflating: __MACOSX/DataSet/train/.__r.tfrecord
#   inflating: DataSet/train/_S.tfrecord
#   inflating: __MACOSX/DataSet/train/.__S.tfrecord
#   inflating: DataSet/train/3l.tfrecord
#   inflating: __MACOSX/DataSet/train/._3l.tfrecord
#   inflating: DataSet/train/3m.tfrecord
#   inflating: __MACOSX/DataSet/train/._3m.tfrecord
#   inflating: DataSet/train/1q.tfrecord
#   inflating: __MACOSX/DataSet/train/._1q.tfrecord
#   inflating: DataSet/train/1p.tfrecord
#   inflating: __MACOSX/DataSet/train/._1p.tfrecord
#   inflating: DataSet/train/3_.tfrecord
#   inflating: __MACOSX/DataSet/train/._3_.tfrecord
#   inflating: DataSet/train/-r.tfrecord
#   inflating: __MACOSX/DataSet/train/._-r.tfrecord
#   inflating: DataSet/train/-S.tfrecord
#   inflating: __MACOSX/DataSet/train/._-S.tfrecord
#   inflating: DataSet/train/0B.tfrecord
#   inflating: __MACOSX/DataSet/train/._0B.tfrecord
#   inflating: DataSet/train/0C.tfrecord
#   inflating: __MACOSX/DataSet/train/._0C.tfrecord
#   inflating: DataSet/train/4k.tfrecord
#   inflating: __MACOSX/DataSet/train/._4k.tfrecord
#   inflating: DataSet/train/4j.tfrecord
#   inflating: __MACOSX/DataSet/train/._4j.tfrecord
#   inflating: DataSet/train/1z.tfrecord
#   inflating: __MACOSX/DataSet/train/._1z.tfrecord
#   inflating: DataSet/train/_X.tfrecord
#   inflating: __MACOSX/DataSet/train/.__X.tfrecord
#   inflating: DataSet/train/_y.tfrecord
#   inflating: __MACOSX/DataSet/train/.__y.tfrecord
#   inflating: DataSet/train/3F.tfrecord
#   inflating: __MACOSX/DataSet/train/._3F.tfrecord
#   inflating: DataSet/train/--.tfrecord
#   inflating: __MACOSX/DataSet/train/._--.tfrecord
#   inflating: DataSet/train/3g.tfrecord
#   inflating: __MACOSX/DataSet/train/._3g.tfrecord
#   inflating: DataSet/train/4a.tfrecord
#   inflating: __MACOSX/DataSet/train/._4a.tfrecord
#   inflating: DataSet/train/0h.tfrecord
#   inflating: __MACOSX/DataSet/train/._0h.tfrecord
#   inflating: DataSet/train/0I.tfrecord
#   inflating: __MACOSX/DataSet/train/._0I.tfrecord
#   inflating: DataSet/train/-x.tfrecord
#   inflating: __MACOSX/DataSet/train/._-x.tfrecord
#   inflating: DataSet/train/2u.tfrecord
#   inflating: __MACOSX/DataSet/train/._2u.tfrecord
#   inflating: DataSet/train/-Y.tfrecord
#   inflating: __MACOSX/DataSet/train/._-Y.tfrecord
#   inflating: DataSet/train/2T.tfrecord
#   inflating: __MACOSX/DataSet/train/._2T.tfrecord
#   inflating: DataSet/train/_-.tfrecord
#   inflating: __MACOSX/DataSet/train/.__-.tfrecord
#   inflating: DataSet/train/-f.tfrecord
#   inflating: __MACOSX/DataSet/train/._-f.tfrecord
#   inflating: DataSet/train/2k.tfrecord
#   inflating: __MACOSX/DataSet/train/._2k.tfrecord
#   inflating: DataSet/train/3-.tfrecord
#   inflating: __MACOSX/DataSet/train/._3-.tfrecord
#   inflating: DataSet/train/-g.tfrecord
#   inflating: __MACOSX/DataSet/train/._-g.tfrecord
#   inflating: DataSet/train/2J.tfrecord
#   inflating: __MACOSX/DataSet/train/._2J.tfrecord
#   inflating: DataSet/train/_3.tfrecord
#   inflating: __MACOSX/DataSet/train/.__3.tfrecord
#   inflating: DataSet/train/_2.tfrecord
#   inflating: __MACOSX/DataSet/train/.__2.tfrecord
#   inflating: DataSet/train/0V.tfrecord
#   inflating: __MACOSX/DataSet/train/._0V.tfrecord
#   inflating: DataSet/train/0w.tfrecord
#   inflating: __MACOSX/DataSet/train/._0w.tfrecord
#   inflating: DataSet/train/_f.tfrecord
#   inflating: __MACOSX/DataSet/train/.__f.tfrecord
#   inflating: DataSet/train/_G.tfrecord
#   inflating: __MACOSX/DataSet/train/.__G.tfrecord
#   inflating: DataSet/train/3X.tfrecord
#   inflating: __MACOSX/DataSet/train/._3X.tfrecord
#   inflating: DataSet/train/-3.tfrecord
#   inflating: __MACOSX/DataSet/train/._-3.tfrecord
#   inflating: DataSet/train/3y.tfrecord
#   inflating: __MACOSX/DataSet/train/._3y.tfrecord
#   inflating: DataSet/train/-2.tfrecord
#   inflating: __MACOSX/DataSet/train/._-2.tfrecord
#   inflating: DataSet/train/1E.tfrecord
#   inflating: __MACOSX/DataSet/train/._1E.tfrecord
#   inflating: DataSet/train/1d.tfrecord
#   inflating: __MACOSX/DataSet/train/._1d.tfrecord
#   inflating: DataSet/train/2a.tfrecord
#   inflating: __MACOSX/DataSet/train/._2a.tfrecord
#   inflating: DataSet/train/-L.tfrecord
#   inflating: __MACOSX/DataSet/train/._-L.tfrecord
#   inflating: DataSet/train/-m.tfrecord
#   inflating: __MACOSX/DataSet/train/._-m.tfrecord
#   inflating: DataSet/train/_9.tfrecord
#   inflating: __MACOSX/DataSet/train/.__9.tfrecord
#   inflating: DataSet/train/_8.tfrecord
#   inflating: __MACOSX/DataSet/train/.__8.tfrecord
#   inflating: DataSet/train/4U.tfrecord
#   inflating: __MACOSX/DataSet/train/._4U.tfrecord
#   inflating: DataSet/train/4T.tfrecord
#   inflating: __MACOSX/DataSet/train/._4T.tfrecord
#   inflating: DataSet/train/-_.tfrecord
#   inflating: __MACOSX/DataSet/train/._-_.tfrecord
#   inflating: DataSet/train/1o.tfrecord
#   inflating: __MACOSX/DataSet/train/._1o.tfrecord
#   inflating: DataSet/train/1n.tfrecord
#   inflating: __MACOSX/DataSet/train/._1n.tfrecord
#   inflating: DataSet/train/_L.tfrecord
#   inflating: __MACOSX/DataSet/train/.__L.tfrecord
#   inflating: DataSet/train/_M.tfrecord
#   inflating: __MACOSX/DataSet/train/.__M.tfrecord
#   inflating: DataSet/train/3r.tfrecord
#   inflating: __MACOSX/DataSet/train/._3r.tfrecord
#   inflating: DataSet/train/-9.tfrecord
#   inflating: __MACOSX/DataSet/train/._-9.tfrecord
#   inflating: DataSet/train/3s.tfrecord
#   inflating: __MACOSX/DataSet/train/._3s.tfrecord
#   inflating: DataSet/train/-8.tfrecord
#   inflating: __MACOSX/DataSet/train/._-8.tfrecord
#   inflating: DataSet/train/__.tfrecord
#   inflating: __MACOSX/DataSet/train/.___.tfrecord
#   inflating: DataSet/val/5v.tfrecord
#   inflating: __MACOSX/DataSet/val/._5v.tfrecord
#   inflating: DataSet/val/40.tfrecord
#   inflating: __MACOSX/DataSet/val/._40.tfrecord
#   inflating: DataSet/val/5w.tfrecord
#   inflating: __MACOSX/DataSet/val/._5w.tfrecord
#   inflating: DataSet/val/41.tfrecord
#   inflating: __MACOSX/DataSet/val/._41.tfrecord
#   inflating: DataSet/val/GR.tfrecord
#   inflating: __MACOSX/DataSet/val/._GR.tfrecord
#   inflating: DataSet/val/f4.tfrecord
#   inflating: __MACOSX/DataSet/val/._f4.tfrecord
#   inflating: DataSet/val/gs.tfrecord
#   inflating: __MACOSX/DataSet/val/._gs.tfrecord
#   inflating: DataSet/val/f5.tfrecord
#   inflating: __MACOSX/DataSet/val/._f5.tfrecord
#   inflating: DataSet/val/7K.tfrecord
#   inflating: __MACOSX/DataSet/val/._7K.tfrecord
#   inflating: DataSet/val/6-.tfrecord
#   inflating: __MACOSX/DataSet/val/._6-.tfrecord
#   inflating: DataSet/val/7j.tfrecord
#   inflating: __MACOSX/DataSet/val/._7j.tfrecord
#   inflating: DataSet/val/eO.tfrecord
#   inflating: __MACOSX/DataSet/val/._eO.tfrecord
#   inflating: DataSet/val/En.tfrecord
#   inflating: __MACOSX/DataSet/val/._En.tfrecord
#   inflating: DataSet/val/aF.tfrecord
#   inflating: __MACOSX/DataSet/val/._aF.tfrecord
#   inflating: DataSet/val/ag.tfrecord
#   inflating: __MACOSX/DataSet/val/._ag.tfrecord
#   inflating: DataSet/val/3b.tfrecord
#   inflating: __MACOSX/DataSet/val/._3b.tfrecord
#   inflating: DataSet/val/3C.tfrecord
#   inflating: __MACOSX/DataSet/val/._3C.tfrecord
#   inflating: DataSet/val/cz.tfrecord
#   inflating: __MACOSX/DataSet/val/._cz.tfrecord
#   inflating: DataSet/val/09.tfrecord
#   inflating: __MACOSX/DataSet/val/._09.tfrecord
#   inflating: DataSet/val/08.tfrecord
#   inflating: __MACOSX/DataSet/val/._08.tfrecord
#   inflating: DataSet/val/HD.tfrecord
#   inflating: __MACOSX/DataSet/val/._HD.tfrecord
#   inflating: DataSet/val/He.tfrecord
#   inflating: __MACOSX/DataSet/val/._He.tfrecord
#   inflating: DataSet/val/fa.tfrecord
#   inflating: __MACOSX/DataSet/val/._fa.tfrecord
#   inflating: DataSet/val/4e.tfrecord
#   inflating: __MACOSX/DataSet/val/._4e.tfrecord
#   inflating: DataSet/val/4D.tfrecord
#   inflating: __MACOSX/DataSet/val/._4D.tfrecord
#   inflating: DataSet/val/6X.tfrecord
#   inflating: __MACOSX/DataSet/val/._6X.tfrecord
#   inflating: DataSet/val/6Y.tfrecord
#   inflating: __MACOSX/DataSet/val/._6Y.tfrecord
#   inflating: DataSet/val/0_.tfrecord
#   inflating: __MACOSX/DataSet/val/._0_.tfrecord
#   inflating: DataSet/val/37.tfrecord
#   inflating: __MACOSX/DataSet/val/._37.tfrecord
#   inflating: DataSet/val/2Q.tfrecord
#   inflating: __MACOSX/DataSet/val/._2Q.tfrecord
#   inflating: DataSet/val/36.tfrecord
#   inflating: __MACOSX/DataSet/val/._36.tfrecord
#   inflating: DataSet/val/2p.tfrecord
#   inflating: __MACOSX/DataSet/val/._2p.tfrecord
#   inflating: DataSet/val/A3.tfrecord
#   inflating: __MACOSX/DataSet/val/._A3.tfrecord
#   inflating: DataSet/val/a2.tfrecord
#   inflating: __MACOSX/DataSet/val/._a2.tfrecord
#   inflating: DataSet/val/0L.tfrecord
#   inflating: __MACOSX/DataSet/val/._0L.tfrecord
#   inflating: DataSet/val/0M.tfrecord
#   inflating: __MACOSX/DataSet/val/._0M.tfrecord
#   inflating: DataSet/val/Bh.tfrecord
#   inflating: __MACOSX/DataSet/val/._Bh.tfrecord
#   inflating: DataSet/val/bI.tfrecord
#   inflating: __MACOSX/DataSet/val/._bI.tfrecord
#   inflating: DataSet/val/9N.tfrecord
#   inflating: __MACOSX/DataSet/val/._9N.tfrecord
#   inflating: DataSet/val/9o.tfrecord
#   inflating: __MACOSX/DataSet/val/._9o.tfrecord
#   inflating: DataSet/val/H1.tfrecord
#   inflating: __MACOSX/DataSet/val/._H1.tfrecord
#   inflating: DataSet/val/H0.tfrecord
#   inflating: __MACOSX/DataSet/val/._H0.tfrecord
#   inflating: DataSet/val/HN.tfrecord
#   inflating: __MACOSX/DataSet/val/._HN.tfrecord
#   inflating: DataSet/val/hO.tfrecord
#   inflating: __MACOSX/DataSet/val/._hO.tfrecord
#   inflating: DataSet/val/91.tfrecord
#   inflating: __MACOSX/DataSet/val/._91.tfrecord
#   inflating: DataSet/val/8W.tfrecord
#   inflating: __MACOSX/DataSet/val/._8W.tfrecord
#   inflating: DataSet/val/90.tfrecord
#   inflating: __MACOSX/DataSet/val/._90.tfrecord
#   inflating: DataSet/val/8V.tfrecord
#   inflating: __MACOSX/DataSet/val/._8V.tfrecord
#   inflating: DataSet/val/B7.tfrecord
#   inflating: __MACOSX/DataSet/val/._B7.tfrecord
#   inflating: DataSet/val/Cq.tfrecord
#   inflating: __MACOSX/DataSet/val/._Cq.tfrecord
#   inflating: DataSet/val/B6.tfrecord
#   inflating: __MACOSX/DataSet/val/._B6.tfrecord
#   inflating: DataSet/val/Cp.tfrecord
#   inflating: __MACOSX/DataSet/val/._Cp.tfrecord
#   inflating: DataSet/val/03.tfrecord
#   inflating: __MACOSX/DataSet/val/._03.tfrecord
#   inflating: DataSet/val/1U.tfrecord
#   inflating: __MACOSX/DataSet/val/._1U.tfrecord
#   inflating: DataSet/val/02.tfrecord
#   inflating: __MACOSX/DataSet/val/._02.tfrecord
#   inflating: DataSet/val/1T.tfrecord
#   inflating: __MACOSX/DataSet/val/._1T.tfrecord
#   inflating: DataSet/val/aL.tfrecord
#   inflating: __MACOSX/DataSet/val/._aL.tfrecord
#   inflating: DataSet/val/_V.tfrecord
#   inflating: __MACOSX/DataSet/val/.__V.tfrecord
#   inflating: DataSet/val/_W.tfrecord
#   inflating: __MACOSX/DataSet/val/.__W.tfrecord
#   inflating: DataSet/val/AM.tfrecord
#   inflating: __MACOSX/DataSet/val/._AM.tfrecord
#   inflating: DataSet/val/3H.tfrecord
#   inflating: __MACOSX/DataSet/val/._3H.tfrecord
#   inflating: DataSet/val/3i.tfrecord
#   inflating: __MACOSX/DataSet/val/._3i.tfrecord
#   inflating: DataSet/val/A_.tfrecord
#   inflating: __MACOSX/DataSet/val/._A_.tfrecord
#   inflating: DataSet/val/7a.tfrecord
#   inflating: __MACOSX/DataSet/val/._7a.tfrecord
#   inflating: DataSet/val/EE.tfrecord
#   inflating: __MACOSX/DataSet/val/._EE.tfrecord
#   inflating: DataSet/val/eD.tfrecord
#   inflating: __MACOSX/DataSet/val/._eD.tfrecord
#   inflating: DataSet/val/gx.tfrecord
#   inflating: __MACOSX/DataSet/val/._gx.tfrecord
#   inflating: DataSet/val/gY.tfrecord
#   inflating: __MACOSX/DataSet/val/._gY.tfrecord
#   inflating: DataSet/val/9D.tfrecord
#   inflating: __MACOSX/DataSet/val/._9D.tfrecord
#   inflating: DataSet/val/9e.tfrecord
#   inflating: __MACOSX/DataSet/val/._9e.tfrecord
#   inflating: DataSet/val/0F.tfrecord
#   inflating: __MACOSX/DataSet/val/._0F.tfrecord
#   inflating: DataSet/val/0g.tfrecord
#   inflating: __MACOSX/DataSet/val/._0g.tfrecord
#   inflating: DataSet/val/Bb.tfrecord
#   inflating: __MACOSX/DataSet/val/._Bb.tfrecord
#   inflating: DataSet/val/bC.tfrecord
#   inflating: __MACOSX/DataSet/val/._bC.tfrecord
#   inflating: DataSet/val/-V.tfrecord
#   inflating: __MACOSX/DataSet/val/._-V.tfrecord
#   inflating: DataSet/val/-W.tfrecord
#   inflating: __MACOSX/DataSet/val/._-W.tfrecord
#   inflating: DataSet/val/2Z.tfrecord
#   inflating: __MACOSX/DataSet/val/._2Z.tfrecord
#   inflating: DataSet/val/a9.tfrecord
#   inflating: __MACOSX/DataSet/val/._a9.tfrecord
#   inflating: DataSet/val/a8.tfrecord
#   inflating: __MACOSX/DataSet/val/._a8.tfrecord
#   inflating: DataSet/val/DV.tfrecord
#   inflating: __MACOSX/DataSet/val/._DV.tfrecord
#   inflating: DataSet/val/e0.tfrecord
#   inflating: __MACOSX/DataSet/val/._e0.tfrecord
#   inflating: DataSet/val/Dw.tfrecord
#   inflating: __MACOSX/DataSet/val/._Dw.tfrecord
#   inflating: DataSet/val/e1.tfrecord
#   inflating: __MACOSX/DataSet/val/._e1.tfrecord
#   inflating: DataSet/val/6R.tfrecord
#   inflating: __MACOSX/DataSet/val/._6R.tfrecord
#   inflating: DataSet/val/74.tfrecord
#   inflating: __MACOSX/DataSet/val/._74.tfrecord
#   inflating: DataSet/val/6S.tfrecord
#   inflating: __MACOSX/DataSet/val/._6S.tfrecord
#   inflating: DataSet/val/75.tfrecord
#   inflating: __MACOSX/DataSet/val/._75.tfrecord
#   inflating: DataSet/val/FK.tfrecord
#   inflating: __MACOSX/DataSet/val/._FK.tfrecord
#   inflating: DataSet/val/g-.tfrecord
#   inflating: __MACOSX/DataSet/val/._g-.tfrecord
#   inflating: DataSet/val/fJ.tfrecord
#   inflating: __MACOSX/DataSet/val/._fJ.tfrecord
#   inflating: DataSet/val/4o.tfrecord
#   inflating: __MACOSX/DataSet/val/._4o.tfrecord
#   inflating: DataSet/val/4n.tfrecord
#   inflating: __MACOSX/DataSet/val/._4n.tfrecord
#   inflating: DataSet/val/6_.tfrecord
#   inflating: __MACOSX/DataSet/val/._6_.tfrecord
#   inflating: DataSet/val/9z.tfrecord
#   inflating: __MACOSX/DataSet/val/._9z.tfrecord
#   inflating: DataSet/val/-H.tfrecord
#   inflating: __MACOSX/DataSet/val/._-H.tfrecord
#   inflating: DataSet/val/2e.tfrecord
#   inflating: __MACOSX/DataSet/val/._2e.tfrecord
#   inflating: DataSet/val/-I.tfrecord
#   inflating: __MACOSX/DataSet/val/._-I.tfrecord
#   inflating: DataSet/val/2d.tfrecord
#   inflating: __MACOSX/DataSet/val/._2d.tfrecord
#   inflating: DataSet/val/0x.tfrecord
#   inflating: __MACOSX/DataSet/val/._0x.tfrecord
#   inflating: DataSet/val/0y.tfrecord
#   inflating: __MACOSX/DataSet/val/._0y.tfrecord
#   inflating: DataSet/val/FU.tfrecord
#   inflating: __MACOSX/DataSet/val/._FU.tfrecord
#   inflating: DataSet/val/g3.tfrecord
#   inflating: __MACOSX/DataSet/val/._g3.tfrecord
#   inflating: DataSet/val/ft.tfrecord
#   inflating: __MACOSX/DataSet/val/._ft.tfrecord
#   inflating: DataSet/val/g2.tfrecord
#   inflating: __MACOSX/DataSet/val/._g2.tfrecord
#   inflating: DataSet/val/4q.tfrecord
#   inflating: __MACOSX/DataSet/val/._4q.tfrecord
#   inflating: DataSet/val/57.tfrecord
#   inflating: __MACOSX/DataSet/val/._57.tfrecord
#   inflating: DataSet/val/4p.tfrecord
#   inflating: __MACOSX/DataSet/val/._4p.tfrecord
#   inflating: DataSet/val/56.tfrecord
#   inflating: __MACOSX/DataSet/val/._56.tfrecord
#   inflating: DataSet/val/Dh.tfrecord
#   inflating: __MACOSX/DataSet/val/._Dh.tfrecord
#   inflating: DataSet/val/dI.tfrecord
#   inflating: __MACOSX/DataSet/val/._dI.tfrecord
#   inflating: DataSet/val/6l.tfrecord
#   inflating: __MACOSX/DataSet/val/._6l.tfrecord
#   inflating: DataSet/val/6m.tfrecord
#   inflating: __MACOSX/DataSet/val/._6m.tfrecord
#   inflating: DataSet/val/8I.tfrecord
#   inflating: __MACOSX/DataSet/val/._8I.tfrecord
#   inflating: DataSet/val/8H.tfrecord
#   inflating: __MACOSX/DataSet/val/._8H.tfrecord
#   inflating: DataSet/val/hP.tfrecord
#   inflating: __MACOSX/DataSet/val/._hP.tfrecord
#   inflating: DataSet/val/Hq.tfrecord
#   inflating: __MACOSX/DataSet/val/._Hq.tfrecord
#   inflating: DataSet/val/Ar.tfrecord
#   inflating: __MACOSX/DataSet/val/._Ar.tfrecord
#   inflating: DataSet/val/_H.tfrecord
#   inflating: __MACOSX/DataSet/val/.__H.tfrecord
#   inflating: DataSet/val/_I.tfrecord
#   inflating: __MACOSX/DataSet/val/.__I.tfrecord
#   inflating: DataSet/val/as.tfrecord
#   inflating: __MACOSX/DataSet/val/._as.tfrecord
#   inflating: DataSet/val/20.tfrecord
#   inflating: __MACOSX/DataSet/val/._20.tfrecord
#   inflating: DataSet/val/3v.tfrecord
#   inflating: __MACOSX/DataSet/val/._3v.tfrecord
#   inflating: DataSet/val/21.tfrecord
#   inflating: __MACOSX/DataSet/val/._21.tfrecord
#   inflating: DataSet/val/3w.tfrecord
#   inflating: __MACOSX/DataSet/val/._3w.tfrecord
#   inflating: DataSet/val/co.tfrecord
#   inflating: __MACOSX/DataSet/val/._co.tfrecord
#   inflating: DataSet/val/Cn.tfrecord
#   inflating: __MACOSX/DataSet/val/._Cn.tfrecord
#   inflating: DataSet/val/0-.tfrecord
#   inflating: __MACOSX/DataSet/val/._0-.tfrecord
#   inflating: DataSet/val/1K.tfrecord
#   inflating: __MACOSX/DataSet/val/._1K.tfrecord
#   inflating: DataSet/val/1j.tfrecord
#   inflating: __MACOSX/DataSet/val/._1j.tfrecord
#   inflating: DataSet/val/5b.tfrecord
#   inflating: __MACOSX/DataSet/val/._5b.tfrecord
#   inflating: DataSet/val/5C.tfrecord
#   inflating: __MACOSX/DataSet/val/._5C.tfrecord
#   inflating: DataSet/val/Gf.tfrecord
#   inflating: __MACOSX/DataSet/val/._Gf.tfrecord
#   inflating: DataSet/val/gg.tfrecord
#   inflating: __MACOSX/DataSet/val/._gg.tfrecord
#   inflating: DataSet/val/69.tfrecord
#   inflating: __MACOSX/DataSet/val/._69.tfrecord
#   inflating: DataSet/val/68.tfrecord
#   inflating: __MACOSX/DataSet/val/._68.tfrecord
#   inflating: DataSet/val/EZ.tfrecord
#   inflating: __MACOSX/DataSet/val/._EZ.tfrecord
#   inflating: DataSet/val/DB.tfrecord
#   inflating: __MACOSX/DataSet/val/._DB.tfrecord
#   inflating: DataSet/val/dC.tfrecord
#   inflating: __MACOSX/DataSet/val/._dC.tfrecord
#   inflating: DataSet/val/6f.tfrecord
#   inflating: __MACOSX/DataSet/val/._6f.tfrecord
#   inflating: DataSet/val/6G.tfrecord
#   inflating: __MACOSX/DataSet/val/._6G.tfrecord
#   inflating: DataSet/val/g9.tfrecord
#   inflating: __MACOSX/DataSet/val/._g9.tfrecord
#   inflating: DataSet/val/G8.tfrecord
#   inflating: __MACOSX/DataSet/val/._G8.tfrecord
#   inflating: DataSet/val/4Z.tfrecord
#   inflating: __MACOSX/DataSet/val/._4Z.tfrecord
#   inflating: DataSet/val/14.tfrecord
#   inflating: __MACOSX/DataSet/val/._14.tfrecord
#   inflating: DataSet/val/0R.tfrecord
#   inflating: __MACOSX/DataSet/val/._0R.tfrecord
#   inflating: DataSet/val/15.tfrecord
#   inflating: __MACOSX/DataSet/val/._15.tfrecord
#   inflating: DataSet/val/0S.tfrecord
#   inflating: __MACOSX/DataSet/val/._0S.tfrecord
#   inflating: DataSet/val/c0.tfrecord
#   inflating: __MACOSX/DataSet/val/._c0.tfrecord
#   inflating: DataSet/val/Bv.tfrecord
#   inflating: __MACOSX/DataSet/val/._Bv.tfrecord
#   inflating: DataSet/val/c1.tfrecord
#   inflating: __MACOSX/DataSet/val/._c1.tfrecord
#   inflating: DataSet/val/bW.tfrecord
#   inflating: __MACOSX/DataSet/val/._bW.tfrecord
#   inflating: DataSet/val/2o.tfrecord
#   inflating: __MACOSX/DataSet/val/._2o.tfrecord
#   inflating: DataSet/val/-b.tfrecord
#   inflating: __MACOSX/DataSet/val/._-b.tfrecord
#   inflating: DataSet/val/2N.tfrecord
#   inflating: __MACOSX/DataSet/val/._2N.tfrecord
#   inflating: DataSet/val/-C.tfrecord
#   inflating: __MACOSX/DataSet/val/._-C.tfrecord
#   inflating: DataSet/val/A-.tfrecord
#   inflating: __MACOSX/DataSet/val/._A-.tfrecord
#   inflating: DataSet/val/_7.tfrecord
#   inflating: __MACOSX/DataSet/val/.__7.tfrecord
#   inflating: DataSet/val/_6.tfrecord
#   inflating: __MACOSX/DataSet/val/.__6.tfrecord
#   inflating: DataSet/val/86.tfrecord
#   inflating: __MACOSX/DataSet/val/._86.tfrecord
#   inflating: DataSet/val/9p.tfrecord
#   inflating: __MACOSX/DataSet/val/._9p.tfrecord
#   inflating: DataSet/val/87.tfrecord
#   inflating: __MACOSX/DataSet/val/._87.tfrecord
#   inflating: DataSet/val/9Q.tfrecord
#   inflating: __MACOSX/DataSet/val/._9Q.tfrecord
#   inflating: DataSet/val/7U.tfrecord
#   inflating: __MACOSX/DataSet/val/._7U.tfrecord
#   inflating: DataSet/val/63.tfrecord
#   inflating: __MACOSX/DataSet/val/._63.tfrecord
#   inflating: DataSet/val/7t.tfrecord
#   inflating: __MACOSX/DataSet/val/._7t.tfrecord
#   inflating: DataSet/val/62.tfrecord
#   inflating: __MACOSX/DataSet/val/._62.tfrecord
#   inflating: DataSet/val/Eq.tfrecord
#   inflating: __MACOSX/DataSet/val/._Eq.tfrecord
#   inflating: DataSet/val/D7.tfrecord
#   inflating: __MACOSX/DataSet/val/._D7.tfrecord
#   inflating: DataSet/val/Ep.tfrecord
#   inflating: __MACOSX/DataSet/val/._Ep.tfrecord
#   inflating: DataSet/val/D6.tfrecord
#   inflating: __MACOSX/DataSet/val/._D6.tfrecord
#   inflating: DataSet/val/5H.tfrecord
#   inflating: __MACOSX/DataSet/val/._5H.tfrecord
#   inflating: DataSet/val/5i.tfrecord
#   inflating: __MACOSX/DataSet/val/._5i.tfrecord
#   inflating: DataSet/val/Gl.tfrecord
#   inflating: __MACOSX/DataSet/val/._Gl.tfrecord
#   inflating: DataSet/val/GM.tfrecord
#   inflating: __MACOSX/DataSet/val/._GM.tfrecord
#   inflating: DataSet/val/ce.tfrecord
#   inflating: __MACOSX/DataSet/val/._ce.tfrecord
#   inflating: DataSet/val/Cd.tfrecord
#   inflating: __MACOSX/DataSet/val/._Cd.tfrecord
#   inflating: DataSet/val/1A.tfrecord
#   inflating: __MACOSX/DataSet/val/._1A.tfrecord
#   inflating: DataSet/val/_b.tfrecord
#   inflating: __MACOSX/DataSet/val/.__b.tfrecord
#   inflating: DataSet/val/AX.tfrecord
#   inflating: __MACOSX/DataSet/val/._AX.tfrecord
#   inflating: DataSet/val/Ay.tfrecord
#   inflating: __MACOSX/DataSet/val/._Ay.tfrecord
#   inflating: DataSet/val/_c.tfrecord
#   inflating: __MACOSX/DataSet/val/.__c.tfrecord
#   inflating: DataSet/val/-7.tfrecord
#   inflating: __MACOSX/DataSet/val/._-7.tfrecord
#   inflating: DataSet/val/-6.tfrecord
#   inflating: __MACOSX/DataSet/val/._-6.tfrecord
#   inflating: DataSet/val/g_.tfrecord
#   inflating: __MACOSX/DataSet/val/._g_.tfrecord
#   inflating: DataSet/val/HZ.tfrecord
#   inflating: __MACOSX/DataSet/val/._HZ.tfrecord
#   inflating: DataSet/val/8c.tfrecord
#   inflating: __MACOSX/DataSet/val/._8c.tfrecord
#   inflating: DataSet/val/8b.tfrecord
#   inflating: __MACOSX/DataSet/val/._8b.tfrecord
#   inflating: DataSet/val/-O.tfrecord
#   inflating: __MACOSX/DataSet/val/._-O.tfrecord
#   inflating: DataSet/val/2B.tfrecord
#   inflating: __MACOSX/DataSet/val/._2B.tfrecord
#   inflating: DataSet/val/-n.tfrecord
#   inflating: __MACOSX/DataSet/val/._-n.tfrecord
#   inflating: DataSet/val/2C.tfrecord
#   inflating: __MACOSX/DataSet/val/._2C.tfrecord
#   inflating: DataSet/val/19.tfrecord
#   inflating: __MACOSX/DataSet/val/._19.tfrecord
#   inflating: DataSet/val/18.tfrecord
#   inflating: __MACOSX/DataSet/val/._18.tfrecord
#   inflating: DataSet/val/bZ.tfrecord
#   inflating: __MACOSX/DataSet/val/._bZ.tfrecord
#   inflating: DataSet/val/fR.tfrecord
#   inflating: __MACOSX/DataSet/val/._fR.tfrecord
#   inflating: DataSet/val/G4.tfrecord
#   inflating: __MACOSX/DataSet/val/._G4.tfrecord
#   inflating: DataSet/val/fs.tfrecord
#   inflating: __MACOSX/DataSet/val/._fs.tfrecord
#   inflating: DataSet/val/G5.tfrecord
#   inflating: __MACOSX/DataSet/val/._G5.tfrecord
#   inflating: DataSet/val/4V.tfrecord
#   inflating: __MACOSX/DataSet/val/._4V.tfrecord
#   inflating: DataSet/val/50.tfrecord
#   inflating: __MACOSX/DataSet/val/._50.tfrecord
#   inflating: DataSet/val/4W.tfrecord
#   inflating: __MACOSX/DataSet/val/._4W.tfrecord
#   inflating: DataSet/val/51.tfrecord
#   inflating: __MACOSX/DataSet/val/._51.tfrecord
#   inflating: DataSet/val/dO.tfrecord
#   inflating: __MACOSX/DataSet/val/._dO.tfrecord
#   inflating: DataSet/val/dn.tfrecord
#   inflating: __MACOSX/DataSet/val/._dn.tfrecord
#   inflating: DataSet/val/6K.tfrecord
#   inflating: __MACOSX/DataSet/val/._6K.tfrecord
#   inflating: DataSet/val/7-.tfrecord
#   inflating: __MACOSX/DataSet/val/._7-.tfrecord
#   inflating: DataSet/val/6j.tfrecord
#   inflating: __MACOSX/DataSet/val/._6j.tfrecord
#   inflating: DataSet/val/Au.tfrecord
#   inflating: __MACOSX/DataSet/val/._Au.tfrecord
#   inflating: DataSet/val/_O.tfrecord
#   inflating: __MACOSX/DataSet/val/.__O.tfrecord
#   inflating: DataSet/val/_n.tfrecord
#   inflating: __MACOSX/DataSet/val/.__n.tfrecord
#   inflating: DataSet/val/aT.tfrecord
#   inflating: __MACOSX/DataSet/val/._aT.tfrecord
#   inflating: DataSet/val/27.tfrecord
#   inflating: __MACOSX/DataSet/val/._27.tfrecord
#   inflating: DataSet/val/3q.tfrecord
#   inflating: __MACOSX/DataSet/val/._3q.tfrecord
#   inflating: DataSet/val/26.tfrecord
#   inflating: __MACOSX/DataSet/val/._26.tfrecord
#   inflating: DataSet/val/3P.tfrecord
#   inflating: __MACOSX/DataSet/val/._3P.tfrecord
#   inflating: DataSet/val/Ch.tfrecord
#   inflating: __MACOSX/DataSet/val/._Ch.tfrecord
#   inflating: DataSet/val/ci.tfrecord
#   inflating: __MACOSX/DataSet/val/._ci.tfrecord
#   inflating: DataSet/val/1L.tfrecord
#   inflating: __MACOSX/DataSet/val/._1L.tfrecord
#   inflating: DataSet/val/1m.tfrecord
#   inflating: __MACOSX/DataSet/val/._1m.tfrecord
#   inflating: DataSet/val/8N.tfrecord
#   inflating: __MACOSX/DataSet/val/._8N.tfrecord
#   inflating: DataSet/val/8o.tfrecord
#   inflating: __MACOSX/DataSet/val/._8o.tfrecord
#   inflating: DataSet/val/i1.tfrecord
#   inflating: __MACOSX/DataSet/val/._i1.tfrecord
#   inflating: DataSet/val/HW.tfrecord
#   inflating: __MACOSX/DataSet/val/._HW.tfrecord
#   inflating: DataSet/val/i0.tfrecord
#   inflating: __MACOSX/DataSet/val/._i0.tfrecord
#   inflating: DataSet/val/Hv.tfrecord
#   inflating: __MACOSX/DataSet/val/._Hv.tfrecord
#   inflating: DataSet/val/5e.tfrecord
#   inflating: __MACOSX/DataSet/val/._5e.tfrecord
#   inflating: DataSet/val/5d.tfrecord
#   inflating: __MACOSX/DataSet/val/._5d.tfrecord
#   inflating: DataSet/val/gA.tfrecord
#   inflating: __MACOSX/DataSet/val/._gA.tfrecord
#   inflating: DataSet/val/7x.tfrecord
#   inflating: __MACOSX/DataSet/val/._7x.tfrecord
#   inflating: DataSet/val/7y.tfrecord
#   inflating: __MACOSX/DataSet/val/._7y.tfrecord
#   inflating: DataSet/val/1_.tfrecord
#   inflating: __MACOSX/DataSet/val/._1_.tfrecord
#   inflating: DataSet/val/De.tfrecord
#   inflating: __MACOSX/DataSet/val/._De.tfrecord
#   inflating: DataSet/val/DD.tfrecord
#   inflating: __MACOSX/DataSet/val/._DD.tfrecord
#   inflating: DataSet/val/6a.tfrecord
#   inflating: __MACOSX/DataSet/val/._6a.tfrecord
#   inflating: DataSet/val/fx.tfrecord
#   inflating: __MACOSX/DataSet/val/._fx.tfrecord
#   inflating: DataSet/val/fy.tfrecord
#   inflating: __MACOSX/DataSet/val/._fy.tfrecord
#   inflating: DataSet/val/81.tfrecord
#   inflating: __MACOSX/DataSet/val/._81.tfrecord
#   inflating: DataSet/val/9w.tfrecord
#   inflating: __MACOSX/DataSet/val/._9w.tfrecord
#   inflating: DataSet/val/80.tfrecord
#   inflating: __MACOSX/DataSet/val/._80.tfrecord
#   inflating: DataSet/val/9V.tfrecord
#   inflating: __MACOSX/DataSet/val/._9V.tfrecord
#   inflating: DataSet/val/13.tfrecord
#   inflating: __MACOSX/DataSet/val/._13.tfrecord
#   inflating: DataSet/val/0U.tfrecord
#   inflating: __MACOSX/DataSet/val/._0U.tfrecord
#   inflating: DataSet/val/12.tfrecord
#   inflating: __MACOSX/DataSet/val/._12.tfrecord
#   inflating: DataSet/val/0T.tfrecord
#   inflating: __MACOSX/DataSet/val/._0T.tfrecord
#   inflating: DataSet/val/c7.tfrecord
#   inflating: __MACOSX/DataSet/val/._c7.tfrecord
#   inflating: DataSet/val/BQ.tfrecord
#   inflating: __MACOSX/DataSet/val/._BQ.tfrecord
#   inflating: DataSet/val/C6.tfrecord
#   inflating: __MACOSX/DataSet/val/._C6.tfrecord
#   inflating: DataSet/val/Bp.tfrecord
#   inflating: __MACOSX/DataSet/val/._Bp.tfrecord
#   inflating: DataSet/val/2h.tfrecord
#   inflating: __MACOSX/DataSet/val/._2h.tfrecord
#   inflating: DataSet/val/-e.tfrecord
#   inflating: __MACOSX/DataSet/val/._-e.tfrecord
#   inflating: DataSet/val/2i.tfrecord
#   inflating: __MACOSX/DataSet/val/._2i.tfrecord
#   inflating: DataSet/val/-D.tfrecord
#   inflating: __MACOSX/DataSet/val/._-D.tfrecord
#   inflating: DataSet/val/_0.tfrecord
#   inflating: __MACOSX/DataSet/val/.__0.tfrecord
#   inflating: DataSet/val/_1.tfrecord
#   inflating: __MACOSX/DataSet/val/.__1.tfrecord
#   inflating: DataSet/val/7r.tfrecord
#   inflating: __MACOSX/DataSet/val/._7r.tfrecord
#   inflating: DataSet/val/64.tfrecord
#   inflating: __MACOSX/DataSet/val/._64.tfrecord
#   inflating: DataSet/val/7S.tfrecord
#   inflating: __MACOSX/DataSet/val/._7S.tfrecord
#   inflating: DataSet/val/65.tfrecord
#   inflating: __MACOSX/DataSet/val/._65.tfrecord
#   inflating: DataSet/val/Ev.tfrecord
#   inflating: __MACOSX/DataSet/val/._Ev.tfrecord
#   inflating: DataSet/val/D0.tfrecord
#   inflating: __MACOSX/DataSet/val/._D0.tfrecord
#   inflating: DataSet/val/Ew.tfrecord
#   inflating: __MACOSX/DataSet/val/._Ew.tfrecord
#   inflating: DataSet/val/D1.tfrecord
#   inflating: __MACOSX/DataSet/val/._D1.tfrecord
#   inflating: DataSet/val/5O.tfrecord
#   inflating: __MACOSX/DataSet/val/._5O.tfrecord
#   inflating: DataSet/val/5N.tfrecord
#   inflating: __MACOSX/DataSet/val/._5N.tfrecord
#   inflating: DataSet/val/Gk.tfrecord
#   inflating: __MACOSX/DataSet/val/._Gk.tfrecord
#   inflating: DataSet/val/f-.tfrecord
#   inflating: __MACOSX/DataSet/val/._f-.tfrecord
#   inflating: DataSet/val/gj.tfrecord
#   inflating: __MACOSX/DataSet/val/._gj.tfrecord
#   inflating: DataSet/val/8D.tfrecord
#   inflating: __MACOSX/DataSet/val/._8D.tfrecord
#   inflating: DataSet/val/8E.tfrecord
#   inflating: __MACOSX/DataSet/val/._8E.tfrecord
#   inflating: DataSet/val/Cb.tfrecord
#   inflating: __MACOSX/DataSet/val/._Cb.tfrecord
#   inflating: DataSet/val/CC.tfrecord
#   inflating: __MACOSX/DataSet/val/._CC.tfrecord
#   inflating: DataSet/val/1f.tfrecord
#   inflating: __MACOSX/DataSet/val/._1f.tfrecord
#   inflating: DataSet/val/1g.tfrecord
#   inflating: __MACOSX/DataSet/val/._1g.tfrecord
#   inflating: DataSet/val/_e.tfrecord
#   inflating: __MACOSX/DataSet/val/.__e.tfrecord
#   inflating: DataSet/val/_D.tfrecord
#   inflating: __MACOSX/DataSet/val/.__D.tfrecord
#   inflating: DataSet/val/-0.tfrecord
#   inflating: __MACOSX/DataSet/val/._-0.tfrecord
#   inflating: DataSet/val/-1.tfrecord
#   inflating: __MACOSX/DataSet/val/._-1.tfrecord
#   inflating: DataSet/val/3z.tfrecord
#   inflating: __MACOSX/DataSet/val/._3z.tfrecord
#   inflating: DataSet/val/5q.tfrecord
#   inflating: __MACOSX/DataSet/val/._5q.tfrecord
#   inflating: DataSet/val/47.tfrecord
#   inflating: __MACOSX/DataSet/val/._47.tfrecord
#   inflating: DataSet/val/5p.tfrecord
#   inflating: __MACOSX/DataSet/val/._5p.tfrecord
#   inflating: DataSet/val/46.tfrecord
#   inflating: __MACOSX/DataSet/val/._46.tfrecord
#   inflating: DataSet/val/gU.tfrecord
#   inflating: __MACOSX/DataSet/val/._gU.tfrecord
#   inflating: DataSet/val/f3.tfrecord
#   inflating: __MACOSX/DataSet/val/._f3.tfrecord
#   inflating: DataSet/val/gt.tfrecord
#   inflating: __MACOSX/DataSet/val/._gt.tfrecord
#   inflating: DataSet/val/f2.tfrecord
#   inflating: __MACOSX/DataSet/val/._f2.tfrecord
#   inflating: DataSet/val/7l.tfrecord
#   inflating: __MACOSX/DataSet/val/._7l.tfrecord
#   inflating: DataSet/val/7m.tfrecord
#   inflating: __MACOSX/DataSet/val/._7m.tfrecord
#   inflating: DataSet/val/eh.tfrecord
#   inflating: __MACOSX/DataSet/val/._eh.tfrecord
#   inflating: DataSet/val/EI.tfrecord
#   inflating: __MACOSX/DataSet/val/._EI.tfrecord
#   inflating: DataSet/val/7_.tfrecord
#   inflating: __MACOSX/DataSet/val/._7_.tfrecord
#   inflating: DataSet/val/8Z.tfrecord
#   inflating: __MACOSX/DataSet/val/._8Z.tfrecord
#   inflating: DataSet/val/hC.tfrecord
#   inflating: __MACOSX/DataSet/val/._hC.tfrecord
#   inflating: DataSet/val/Hb.tfrecord
#   inflating: __MACOSX/DataSet/val/._Hb.tfrecord
#   inflating: DataSet/val/Aa.tfrecord
#   inflating: __MACOSX/DataSet/val/._Aa.tfrecord
#   inflating: DataSet/val/_Z.tfrecord
#   inflating: __MACOSX/DataSet/val/.__Z.tfrecord
#   inflating: DataSet/val/3e.tfrecord
#   inflating: __MACOSX/DataSet/val/._3e.tfrecord
#   inflating: DataSet/val/3D.tfrecord
#   inflating: __MACOSX/DataSet/val/._3D.tfrecord
#   inflating: DataSet/val/1x.tfrecord
#   inflating: __MACOSX/DataSet/val/._1x.tfrecord
#   inflating: DataSet/val/1y.tfrecord
#   inflating: __MACOSX/DataSet/val/._1y.tfrecord
#   inflating: DataSet/val/Ff.tfrecord
#   inflating: __MACOSX/DataSet/val/._Ff.tfrecord
#   inflating: DataSet/val/FG.tfrecord
#   inflating: __MACOSX/DataSet/val/._FG.tfrecord
#   inflating: DataSet/val/4b.tfrecord
#   inflating: __MACOSX/DataSet/val/._4b.tfrecord
#   inflating: DataSet/val/4C.tfrecord
#   inflating: __MACOSX/DataSet/val/._4C.tfrecord
#   inflating: DataSet/val/DZ.tfrecord
#   inflating: __MACOSX/DataSet/val/._DZ.tfrecord
#   inflating: DataSet/val/79.tfrecord
#   inflating: __MACOSX/DataSet/val/._79.tfrecord
#   inflating: DataSet/val/78.tfrecord
#   inflating: __MACOSX/DataSet/val/._78.tfrecord
#   inflating: DataSet/val/9i.tfrecord
# ...
#   inflating: __MACOSX/DataSet/val/._5X.tfrecord
#   inflating: DataSet/val/5Y.tfrecord
#   inflating: __MACOSX/DataSet/val/._5Y.tfrecord
#   inflating: DataSet/val/7E.tfrecord
#   inflating: __MACOSX/DataSet/val/._7E.tfrecord
#   inflating: DataSet/val/7d.tfrecord
#   inflating: __MACOSX/DataSet/val/._7d.tfrecord
#   inflating: DataSet/val/EA.tfrecord
#   inflating: __MACOSX/DataSet/val/._EA.tfrecord
#   inflating: DataSet/val/3_.tfrecord
#   inflating: __MACOSX/DataSet/val/._3_.tfrecord
#   inflating: DataSet/val/-r.tfrecord
#   inflating: __MACOSX/DataSet/val/._-r.tfrecord
#   inflating: DataSet/val/39.tfrecord
#   inflating: __MACOSX/DataSet/val/._39.tfrecord
#   inflating: DataSet/val/-S.tfrecord
#   inflating: __MACOSX/DataSet/val/._-S.tfrecord
#   inflating: DataSet/val/38.tfrecord
#   inflating: __MACOSX/DataSet/val/._38.tfrecord
#   inflating: DataSet/val/0B.tfrecord
#   inflating: __MACOSX/DataSet/val/._0B.tfrecord
#   inflating: DataSet/val/0C.tfrecord
#   inflating: __MACOSX/DataSet/val/._0C.tfrecord
#   inflating: DataSet/val/bf.tfrecord
#   inflating: __MACOSX/DataSet/val/._bf.tfrecord
#   inflating: DataSet/val/bg.tfrecord
#   inflating: __MACOSX/DataSet/val/._bg.tfrecord
#   inflating: DataSet/val/9A.tfrecord
#   inflating: __MACOSX/DataSet/val/._9A.tfrecord
#   inflating: DataSet/val/FO.tfrecord
#   inflating: __MACOSX/DataSet/val/._FO.tfrecord
#   inflating: DataSet/val/FN.tfrecord
#   inflating: __MACOSX/DataSet/val/._FN.tfrecord
#   inflating: DataSet/val/5-.tfrecord
#   inflating: __MACOSX/DataSet/val/._5-.tfrecord
#   inflating: DataSet/val/4k.tfrecord
#   inflating: __MACOSX/DataSet/val/._4k.tfrecord
#   inflating: DataSet/val/4j.tfrecord
#   inflating: __MACOSX/DataSet/val/._4j.tfrecord
#   inflating: DataSet/val/E4.tfrecord
#   inflating: __MACOSX/DataSet/val/._E4.tfrecord
#   inflating: DataSet/val/Dr.tfrecord
#   inflating: __MACOSX/DataSet/val/._Dr.tfrecord
#   inflating: DataSet/val/E5.tfrecord
#   inflating: __MACOSX/DataSet/val/._E5.tfrecord
#   inflating: DataSet/val/Ds.tfrecord
#   inflating: __MACOSX/DataSet/val/._Ds.tfrecord
#   inflating: DataSet/val/70.tfrecord
#   inflating: __MACOSX/DataSet/val/._70.tfrecord
#   inflating: DataSet/val/6V.tfrecord
#   inflating: __MACOSX/DataSet/val/._6V.tfrecord
#   inflating: DataSet/val/71.tfrecord
#   inflating: __MACOSX/DataSet/val/._71.tfrecord
#   inflating: DataSet/val/6w.tfrecord
#   inflating: __MACOSX/DataSet/val/._6w.tfrecord
#   inflating: DataSet/val/7O.tfrecord
#   inflating: __MACOSX/DataSet/val/._7O.tfrecord
#   inflating: DataSet/val/7N.tfrecord
#   inflating: __MACOSX/DataSet/val/._7N.tfrecord
#   inflating: DataSet/val/D-.tfrecord
#   inflating: __MACOSX/DataSet/val/._D-.tfrecord
#   inflating: DataSet/val/eK.tfrecord
#   inflating: __MACOSX/DataSet/val/._eK.tfrecord
#   inflating: DataSet/val/EJ.tfrecord
#   inflating: __MACOSX/DataSet/val/._EJ.tfrecord
#   inflating: DataSet/val/44.tfrecord
#   inflating: __MACOSX/DataSet/val/._44.tfrecord
#   inflating: DataSet/val/5R.tfrecord
#   inflating: __MACOSX/DataSet/val/._5R.tfrecord
#   inflating: DataSet/val/45.tfrecord
#   inflating: __MACOSX/DataSet/val/._45.tfrecord
#   inflating: DataSet/val/5s.tfrecord
#   inflating: __MACOSX/DataSet/val/._5s.tfrecord
#   inflating: DataSet/val/F0.tfrecord
#   inflating: __MACOSX/DataSet/val/._F0.tfrecord
#   inflating: DataSet/val/GV.tfrecord
#   inflating: __MACOSX/DataSet/val/._GV.tfrecord
#   inflating: DataSet/val/f1.tfrecord
#   inflating: __MACOSX/DataSet/val/._f1.tfrecord
#   inflating: DataSet/val/Gw.tfrecord
#   inflating: __MACOSX/DataSet/val/._Gw.tfrecord
#   inflating: DataSet/val/Ha.tfrecord
#   inflating: __MACOSX/DataSet/val/._Ha.tfrecord
#   inflating: DataSet/val/8Y.tfrecord
#   inflating: __MACOSX/DataSet/val/._8Y.tfrecord
#   inflating: DataSet/val/8x.tfrecord
#   inflating: __MACOSX/DataSet/val/._8x.tfrecord
#   inflating: DataSet/val/b9.tfrecord
#   inflating: __MACOSX/DataSet/val/._b9.tfrecord
#   inflating: DataSet/val/B8.tfrecord
#   inflating: __MACOSX/DataSet/val/._B8.tfrecord
#   inflating: DataSet/val/1z.tfrecord
#   inflating: __MACOSX/DataSet/val/._1z.tfrecord
#   inflating: DataSet/val/AB.tfrecord
#   inflating: __MACOSX/DataSet/val/._AB.tfrecord
#   inflating: DataSet/val/_X.tfrecord
#   inflating: __MACOSX/DataSet/val/.__X.tfrecord
#   inflating: DataSet/val/_Y.tfrecord
#   inflating: __MACOSX/DataSet/val/.__Y.tfrecord
#   inflating: DataSet/val/aC.tfrecord
#   inflating: __MACOSX/DataSet/val/._aC.tfrecord
#   inflating: DataSet/val/3F.tfrecord
#   inflating: __MACOSX/DataSet/val/._3F.tfrecord
#   inflating: DataSet/val/--.tfrecord
#   inflating: __MACOSX/DataSet/val/._--.tfrecord
#   inflating: DataSet/val/3g.tfrecord
#   inflating: __MACOSX/DataSet/val/._3g.tfrecord
#   inflating: DataSet/val/B_.tfrecord
#   inflating: __MACOSX/DataSet/val/._B_.tfrecord
#   inflating: DataSet/val/DX.tfrecord
#   inflating: __MACOSX/DataSet/val/._DX.tfrecord
#   inflating: DataSet/val/dY.tfrecord
#   inflating: __MACOSX/DataSet/val/._dY.tfrecord
#   inflating: DataSet/val/fE.tfrecord
#   inflating: __MACOSX/DataSet/val/._fE.tfrecord
#   inflating: DataSet/val/Fd.tfrecord
#   inflating: __MACOSX/DataSet/val/._Fd.tfrecord
#   inflating: DataSet/val/4a.tfrecord
#   inflating: __MACOSX/DataSet/val/._4a.tfrecord
#   inflating: DataSet/val/H5.tfrecord
#   inflating: __MACOSX/DataSet/val/._H5.tfrecord
#   inflating: DataSet/val/h4.tfrecord
#   inflating: __MACOSX/DataSet/val/._h4.tfrecord
#   inflating: DataSet/val/9j.tfrecord
#   inflating: __MACOSX/DataSet/val/._9j.tfrecord
#   inflating: DataSet/val/9K.tfrecord
#   inflating: __MACOSX/DataSet/val/._9K.tfrecord
#   inflating: DataSet/val/8-.tfrecord
#   inflating: __MACOSX/DataSet/val/._8-.tfrecord
#   inflating: DataSet/val/0h.tfrecord
#   inflating: __MACOSX/DataSet/val/._0h.tfrecord
#   inflating: DataSet/val/0I.tfrecord
#   inflating: __MACOSX/DataSet/val/._0I.tfrecord
#   inflating: DataSet/val/Bl.tfrecord
#   inflating: __MACOSX/DataSet/val/._Bl.tfrecord
#   inflating: DataSet/val/bm.tfrecord
#   inflating: __MACOSX/DataSet/val/._bm.tfrecord
#   inflating: DataSet/val/-x.tfrecord
#   inflating: __MACOSX/DataSet/val/._-x.tfrecord
#   inflating: DataSet/val/2u.tfrecord
#   inflating: __MACOSX/DataSet/val/._2u.tfrecord
#   inflating: DataSet/val/33.tfrecord
#   inflating: __MACOSX/DataSet/val/._33.tfrecord
#   inflating: DataSet/val/-Y.tfrecord
#   inflating: __MACOSX/DataSet/val/._-Y.tfrecord
#   inflating: DataSet/val/2T.tfrecord
#   inflating: __MACOSX/DataSet/val/._2T.tfrecord
#   inflating: DataSet/val/32.tfrecord
#   inflating: __MACOSX/DataSet/val/._32.tfrecord
#   inflating: DataSet/val/_-.tfrecord
#   inflating: __MACOSX/DataSet/val/.__-.tfrecord
#   inflating: DataSet/val/A7.tfrecord
#   inflating: __MACOSX/DataSet/val/._A7.tfrecord
#   inflating: DataSet/val/A6.tfrecord
#   inflating: __MACOSX/DataSet/val/._A6.tfrecord
#   inflating: DataSet/val/i_.tfrecord
#   inflating: __MACOSX/DataSet/val/._i_.tfrecord
#   inflating: DataSet/val/FZ.tfrecord
#   inflating: __MACOSX/DataSet/val/._FZ.tfrecord
#   inflating: DataSet/val/59.tfrecord
#   inflating: __MACOSX/DataSet/val/._59.tfrecord
#   inflating: DataSet/val/58.tfrecord
#   inflating: __MACOSX/DataSet/val/._58.tfrecord
#   inflating: DataSet/val/df.tfrecord
#   inflating: __MACOSX/DataSet/val/._df.tfrecord
#   inflating: DataSet/val/dG.tfrecord
#   inflating: __MACOSX/DataSet/val/._dG.tfrecord
#   inflating: DataSet/val/6b.tfrecord
#   inflating: __MACOSX/DataSet/val/._6b.tfrecord
#   inflating: DataSet/val/6c.tfrecord
#   inflating: __MACOSX/DataSet/val/._6c.tfrecord
#   inflating: DataSet/val/9T.tfrecord
#   inflating: __MACOSX/DataSet/val/._9T.tfrecord
#   inflating: DataSet/val/82.tfrecord
#   inflating: __MACOSX/DataSet/val/._82.tfrecord
#   inflating: DataSet/val/9U.tfrecord
#   inflating: __MACOSX/DataSet/val/._9U.tfrecord
#   inflating: DataSet/val/83.tfrecord
#   inflating: __MACOSX/DataSet/val/._83.tfrecord
#   inflating: DataSet/val/-f.tfrecord
#   inflating: __MACOSX/DataSet/val/._-f.tfrecord
#   inflating: DataSet/val/2k.tfrecord
#   inflating: __MACOSX/DataSet/val/._2k.tfrecord
#   inflating: DataSet/val/3-.tfrecord
#   inflating: __MACOSX/DataSet/val/._3-.tfrecord
#   inflating: DataSet/val/-g.tfrecord
#   inflating: __MACOSX/DataSet/val/._-g.tfrecord
#   inflating: DataSet/val/2J.tfrecord
#   inflating: __MACOSX/DataSet/val/._2J.tfrecord
#   inflating: DataSet/val/_3.tfrecord
#   inflating: __MACOSX/DataSet/val/.__3.tfrecord
#   inflating: DataSet/val/_2.tfrecord
#   inflating: __MACOSX/DataSet/val/.__2.tfrecord
#   inflating: DataSet/val/0V.tfrecord
#   inflating: __MACOSX/DataSet/val/._0V.tfrecord
#   inflating: DataSet/val/10.tfrecord
#   inflating: __MACOSX/DataSet/val/._10.tfrecord
#   inflating: DataSet/val/0w.tfrecord
#   inflating: __MACOSX/DataSet/val/._0w.tfrecord
#   inflating: DataSet/val/11.tfrecord
#   inflating: __MACOSX/DataSet/val/._11.tfrecord
#   inflating: DataSet/val/bR.tfrecord
#   inflating: __MACOSX/DataSet/val/._bR.tfrecord
#   inflating: DataSet/val/C4.tfrecord
#   inflating: __MACOSX/DataSet/val/._C4.tfrecord
#   inflating: DataSet/val/Bs.tfrecord
#   inflating: __MACOSX/DataSet/val/._Bs.tfrecord
#   inflating: DataSet/val/C5.tfrecord
#   inflating: __MACOSX/DataSet/val/._C5.tfrecord
#   inflating: DataSet/val/5L.tfrecord
#   inflating: __MACOSX/DataSet/val/._5L.tfrecord
#   inflating: DataSet/val/5M.tfrecord
#   inflating: __MACOSX/DataSet/val/._5M.tfrecord
#   inflating: DataSet/val/gh.tfrecord
#   inflating: __MACOSX/DataSet/val/._gh.tfrecord
#   inflating: DataSet/val/GI.tfrecord
#   inflating: __MACOSX/DataSet/val/._GI.tfrecord
#   inflating: DataSet/val/67.tfrecord
#   inflating: __MACOSX/DataSet/val/._67.tfrecord
#   inflating: DataSet/val/7q.tfrecord
#   inflating: __MACOSX/DataSet/val/._7q.tfrecord
#   inflating: DataSet/val/66.tfrecord
#   inflating: __MACOSX/DataSet/val/._66.tfrecord
#   inflating: DataSet/val/7p.tfrecord
#   inflating: __MACOSX/DataSet/val/._7p.tfrecord
#   inflating: DataSet/val/d3.tfrecord
#   inflating: __MACOSX/DataSet/val/._d3.tfrecord
#   inflating: DataSet/val/EU.tfrecord
#   inflating: __MACOSX/DataSet/val/._EU.tfrecord
#   inflating: DataSet/val/D2.tfrecord
#   inflating: __MACOSX/DataSet/val/._D2.tfrecord
#   inflating: DataSet/val/ET.tfrecord
#   inflating: __MACOSX/DataSet/val/._ET.tfrecord
#   inflating: DataSet/val/8G.tfrecord
#   inflating: __MACOSX/DataSet/val/._8G.tfrecord
#   inflating: DataSet/val/8F.tfrecord
#   inflating: __MACOSX/DataSet/val/._8F.tfrecord
#   inflating: DataSet/val/5_.tfrecord
#   inflating: __MACOSX/DataSet/val/._5_.tfrecord
#   inflating: DataSet/val/_f.tfrecord
#   inflating: __MACOSX/DataSet/val/.__f.tfrecord
#   inflating: DataSet/val/_G.tfrecord
#   inflating: __MACOSX/DataSet/val/.__G.tfrecord
#   inflating: DataSet/val/3X.tfrecord
#   inflating: __MACOSX/DataSet/val/._3X.tfrecord
#   inflating: DataSet/val/-3.tfrecord
#   inflating: __MACOSX/DataSet/val/._-3.tfrecord
#   inflating: DataSet/val/3y.tfrecord
#   inflating: __MACOSX/DataSet/val/._3y.tfrecord
#   inflating: DataSet/val/-2.tfrecord
#   inflating: __MACOSX/DataSet/val/._-2.tfrecord
#   inflating: DataSet/val/CA.tfrecord
#   inflating: __MACOSX/DataSet/val/._CA.tfrecord
#   inflating: DataSet/val/1E.tfrecord
#   inflating: __MACOSX/DataSet/val/._1E.tfrecord
#   inflating: DataSet/val/1d.tfrecord
#   inflating: __MACOSX/DataSet/val/._1d.tfrecord
#   inflating: DataSet/val/bx.tfrecord
#   inflating: __MACOSX/DataSet/val/._bx.tfrecord
#   inflating: DataSet/val/By.tfrecord
#   inflating: __MACOSX/DataSet/val/._By.tfrecord
#   inflating: DataSet/val/2a.tfrecord
#   inflating: __MACOSX/DataSet/val/._2a.tfrecord
#   inflating: DataSet/val/-L.tfrecord
#   inflating: __MACOSX/DataSet/val/._-L.tfrecord
#   inflating: DataSet/val/-m.tfrecord
#   inflating: __MACOSX/DataSet/val/._-m.tfrecord
#   inflating: DataSet/val/_9.tfrecord
#   inflating: __MACOSX/DataSet/val/.__9.tfrecord
#   inflating: DataSet/val/_8.tfrecord
#   inflating: __MACOSX/DataSet/val/.__8.tfrecord
#   inflating: DataSet/val/88.tfrecord
#   inflating: __MACOSX/DataSet/val/._88.tfrecord
#   inflating: DataSet/val/89.tfrecord
#   inflating: __MACOSX/DataSet/val/._89.tfrecord
#   inflating: DataSet/val/D_.tfrecord
#   inflating: __MACOSX/DataSet/val/._D_.tfrecord
#   inflating: DataSet/val/dl.tfrecord
#   inflating: __MACOSX/DataSet/val/._dl.tfrecord
#   inflating: DataSet/val/dm.tfrecord
#   inflating: __MACOSX/DataSet/val/._dm.tfrecord
#   inflating: DataSet/val/6H.tfrecord
#   inflating: __MACOSX/DataSet/val/._6H.tfrecord
#   inflating: DataSet/val/6I.tfrecord
#   inflating: __MACOSX/DataSet/val/._6I.tfrecord
#   inflating: DataSet/val/G7.tfrecord
#   inflating: __MACOSX/DataSet/val/._G7.tfrecord
#   inflating: DataSet/val/FQ.tfrecord
#   inflating: __MACOSX/DataSet/val/._FQ.tfrecord
#   inflating: DataSet/val/g6.tfrecord
#   inflating: __MACOSX/DataSet/val/._g6.tfrecord
#   inflating: DataSet/val/fP.tfrecord
#   inflating: __MACOSX/DataSet/val/._fP.tfrecord
#   inflating: DataSet/val/53.tfrecord
#   inflating: __MACOSX/DataSet/val/._53.tfrecord
#   inflating: DataSet/val/4U.tfrecord
#   inflating: __MACOSX/DataSet/val/._4U.tfrecord
#   inflating: DataSet/val/52.tfrecord
#   inflating: __MACOSX/DataSet/val/._52.tfrecord
#   inflating: DataSet/val/4T.tfrecord
#   inflating: __MACOSX/DataSet/val/._4T.tfrecord
#   inflating: DataSet/val/-_.tfrecord
#   inflating: __MACOSX/DataSet/val/._-_.tfrecord
#   inflating: DataSet/val/ck.tfrecord
#   inflating: __MACOSX/DataSet/val/._ck.tfrecord
#   inflating: DataSet/val/B-.tfrecord
#   inflating: __MACOSX/DataSet/val/._B-.tfrecord
#   inflating: DataSet/val/Cj.tfrecord
#   inflating: __MACOSX/DataSet/val/._Cj.tfrecord
#   inflating: DataSet/val/1o.tfrecord
#   inflating: __MACOSX/DataSet/val/._1o.tfrecord
#   inflating: DataSet/val/1n.tfrecord
#   inflating: __MACOSX/DataSet/val/._1n.tfrecord
#   inflating: DataSet/val/_L.tfrecord
#   inflating: __MACOSX/DataSet/val/.__L.tfrecord
#   inflating: DataSet/val/aV.tfrecord
#   inflating: __MACOSX/DataSet/val/._aV.tfrecord
#   inflating: DataSet/val/AW.tfrecord
#   inflating: __MACOSX/DataSet/val/._AW.tfrecord
#   inflating: DataSet/val/_M.tfrecord
#   inflating: __MACOSX/DataSet/val/.__M.tfrecord
#   inflating: DataSet/val/3r.tfrecord
#   inflating: __MACOSX/DataSet/val/._3r.tfrecord
#   inflating: DataSet/val/-9.tfrecord
#   inflating: __MACOSX/DataSet/val/._-9.tfrecord
#   inflating: DataSet/val/24.tfrecord
#   inflating: __MACOSX/DataSet/val/._24.tfrecord
#   inflating: DataSet/val/3s.tfrecord
#   inflating: __MACOSX/DataSet/val/._3s.tfrecord
#   inflating: DataSet/val/-8.tfrecord
#   inflating: __MACOSX/DataSet/val/._-8.tfrecord
#   inflating: DataSet/val/25.tfrecord
#   inflating: __MACOSX/DataSet/val/._25.tfrecord
#   inflating: DataSet/val/Ht.tfrecord
#   inflating: __MACOSX/DataSet/val/._Ht.tfrecord
#   inflating: DataSet/val/Hu.tfrecord
#   inflating: __MACOSX/DataSet/val/._Hu.tfrecord
#   inflating: DataSet/val/8M.tfrecord
#   inflating: __MACOSX/DataSet/val/._8M.tfrecord
#   inflating: DataSet/val/8L.tfrecord
#   inflating: __MACOSX/DataSet/val/._8L.tfrecord
#   inflating: DataSet/val/8_.tfrecord
#   inflating: __MACOSX/DataSet/val/._8_.tfrecord
#   inflating: DataSet/val/7z.tfrecord
#   inflating: __MACOSX/DataSet/val/._7z.tfrecord
#   inflating: DataSet/val/d9.tfrecord
#   inflating: __MACOSX/DataSet/val/._d9.tfrecord
#   inflating: DataSet/val/D8.tfrecord
#   inflating: __MACOSX/DataSet/val/._D8.tfrecord
#   inflating: DataSet/val/5F.tfrecord
#   inflating: __MACOSX/DataSet/val/._5F.tfrecord
#   inflating: DataSet/val/5G.tfrecord
#   inflating: __MACOSX/DataSet/val/._5G.tfrecord
#   inflating: DataSet/val/gb.tfrecord
#   inflating: __MACOSX/DataSet/val/._gb.tfrecord
#   inflating: DataSet/val/gC.tfrecord
#   inflating: __MACOSX/DataSet/val/._gC.tfrecord
#   inflating: DataSet/val/__.tfrecord
#   inflating: __MACOSX/DataSet/val/.___.tfrecord

# %%
# !ls
# Out:
# DataSet  __MACOSX  sample_data

# %%
def fetch_model():
  new_model = Sequential()
  new_model.add(BatchNormalization(input_shape=(10, 128)))  # The input shape excludes batch
  new_model.add(Flatten())
  new_model.add(Dense(2048, activation="relu"))
  new_model.add(Dense(audioset_label_count, activation="sigmoid"))
  new_model.compile("adam", loss="binary_crossentropy", metrics=["accuracy"])
  return new_model


def parser(record, training=True, total_label_count=528):
  context_features = {
    "start_time_seconds": tf.FixedLenFeature([], dtype=tf.float32),
    "end_time_seconds": tf.FixedLenFeature([], dtype=tf.float32),
    "video_id": tf.FixedLenFeature([], dtype=tf.string),
  }
  sequence_features = {
    "audio_embedding": tf.FixedLenSequenceFeature([], dtype=tf.string)
  }

  # In training mode labels will be returned, otherwise they won't be
  if training:
    context_features["labels"] = tf.VarLenFeature(tf.int64)

  context_parsed, sequence_parsed = tf.parse_single_sequence_example(record, context_features, sequence_features)

  x = sequence_parsed['audio_embedding']
  if training:
    y = tf.sparse_to_dense(context_parsed["labels"].values, [total_label_count], 1)
    return x, y
  else:
    return x

    
def make_dataset_provider(tf_records, repeats=1000, num_parallel_calls=12, batch_size=32, total_label_count=100):
  def my_parser(record): return parser(record, total_label_count=total_label_count)

  dataset = tf.data.TFRecordDataset(tf_records)
  dataset = dataset.map(map_func=my_parser, num_parallel_calls=num_parallel_calls)
  dataset = dataset.repeat(repeats)

  dataset = dataset.shuffle(buffer_size=1000)
  dataset = dataset.batch(batch_size)
  d_iter = dataset.make_one_shot_iterator()
  return d_iter


def data_generator(tf_records, batch_size=1, repeats=1000, num_parallel_calls=12, total_label_count=528):
  """
  :return: Data in shape (batch_size, n_frames=10, 128 features - 1 byte each)
  """
  tf_provider = make_dataset_provider(tf_records, repeats=repeats, num_parallel_calls=num_parallel_calls, batch_size=batch_size,
                                      total_label_count=total_label_count)
  sess = tf.compat.v1.Session()

  next_el = tf_provider.get_next()
  max_frames = 10
  while True:
    try:
      raw_x, y = sess.run(next_el)  # returns (batch_size, n_frames, 128)
      x = []
      for entry in raw_x:
        n_frames = entry.shape[0]  # Entry has a shape (n_frames, )
        audio_frame = []
        for i_frame in range(n_frames):
          frame = np.frombuffer(entry[i_frame], np.uint8).astype(np.float32)
          # print("trigger appending a frame of size {}".format(len(float_frames)))
          audio_frame.append(frame)

        if n_frames < max_frames:
          pad = [np.zeros([128], np.float32) for i in range(max_frames-n_frames)]
          audio_frame += pad

        x.append(audio_frame)

      # print("audio_frame.shape=({}, {}, {}). y.shape()={}".format(len(x), len(x[0]), len(x[0][0]), len(y)))
      for i in range(len(x)):
        if len(x[i]) != 10:
          print("ERROR-1")
        for j in range(len(x[i])):
          if len(x[i][j]) != 128:
            print("ERROR-2")

      yield np.array(x), np.array(y)
    except tf.errors.OutOfRangeError:
      print("Iterations exhausted")
      break

# %%
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Flatten

import tensorflow as tf
import os
import pandas as pd
import numpy as np
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
dirname = os.path.abspath('')
bal_train_folder = os.path.join(dirname, 'DataSet/train')
eval_folder = os.path.join(dirname, 'DataSet/val')
print('Train folder: ', bal_train_folder)
print('Eval folder: ', eval_folder)

def get_record(folder, file_names):
  files_glob = []
  for name in file_names:
    files_glob.append("{}/{}".format(folder, name))

  return files_glob


def get_bal_record(file_names):
  return get_record(bal_train_folder, file_names)


def get_eval_record(file_names):
  return get_record(eval_folder, file_names)
# Out:
# Train folder:  /content/DataSet/train
# Eval folder:  /content/DataSet/val

# %%
train_data = []
eval_data = []
batch_size = 3
audioset_label_count = 528

for file in os.listdir(bal_train_folder):
  if file.endswith(".tfrecord"):
    train_data.append(os.path.join(bal_train_folder, file))

for file in os.listdir(eval_folder):
  if file.endswith(".tfrecord"):
    eval_data.append(os.path.join(eval_folder, file))

print('Total training file records: ', len(train_data))
print('Total eval file records: ', len(eval_data))
# Out:
# Total training file records:  219
# Total eval file records:  764

# %%
train_generator = data_generator(train_data, batch_size=batch_size, num_parallel_calls=1)
validation_generator = data_generator(eval_data, batch_size=batch_size, num_parallel_calls=1)
model = fetch_model()
model.summary()

model.fit_generator(train_generator,  
                    steps_per_epoch=len(train_data),
                    epochs=10,
                    validation_data=validation_generator,
                    validation_steps=10)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_2 (Batch (None, 10, 128)           512
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2048)              2623488
# _________________________________________________________________
# dense_4 (Dense)              (None, 528)               1081872
# =================================================================
# Total params: 3,705,872
# Trainable params: 3,705,616
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/10
#  20/219 [=>............................] - ETA: 16s - loss: 0.1337 - accuracy: 0.9518
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#
# InvalidArgumentError: Cannot batch tensors with different shapes in component 0. First element had shape [10] and element 2 had shape [8].
# 	 [[{{node IteratorGetNext}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-12-e44b68a1774b> in <module>()
#       8                     epochs=10,
#       9                     validation_data=validation_generator,
# ---> 10                     validation_steps=10)
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     183             batch_index = 0
#     184             while steps_done < steps_per_epoch:
# --> 185                 generator_output = next(output_generator)
#     186
#     187                 if not hasattr(generator_output, '__len__'):
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py in get(self)
#     740                     "`use_multiprocessing=False, workers > 1`."
#     741                     "For more information see issue #1638.")
# --> 742             six.reraise(*sys.exc_info())
#
# /usr/local/lib/python3.6/dist-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py in get(self)
#     709                 try:
#     710                     future = self.queue.get(block=True)
# --> 711                     inputs = future.get(timeout=30)
#     712                     self.queue.task_done()
#     713                 except mp.TimeoutError:
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# /usr/lib/python3.6/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception and func is not _helper_reraises_exception:
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py in next_sample(uid)
#     648         The next value of generator `uid`.
#     649     """
# --> 650     return six.next(_SHARED_SEQUENCES[uid])
#     651
#     652
#
# <ipython-input-5-601adf5e263b> in data_generator(tf_records, batch_size, repeats, num_parallel_calls, total_label_count)
#      58   while True:
#      59     try:
# ---> 60       raw_x, y = sess.run(next_el)  # returns (batch_size, n_frames, 128)
#      61       x = []
#      62       for entry in raw_x:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1368           pass
#    1369       message = error_interpolation.interpolate(message, self._graph)
# -> 1370       raise type(e)(node_def, op, message)
#    1371
#    1372   def _extend_graph(self):
#
# InvalidArgumentError: Cannot batch tensors with different shapes in component 0. First element had shape [10] and element 2 had shape [8].
# 	 [[node IteratorGetNext (defined at <ipython-input-5-601adf5e263b>:56) ]]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node IteratorGetNext:
#  OneShotIterator (defined at <ipython-input-5-601adf5e263b>:44)
#
# Original stack trace for 'IteratorGetNext':
#   File "/usr/lib/python3.6/threading.py", line 884, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py", line 650, in next_sample
#     return six.next(_SHARED_SEQUENCES[uid])
#   File "<ipython-input-5-601adf5e263b>", line 56, in data_generator
#     next_el = tf_provider.get_next()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/iterator_ops.py", line 426, in get_next
#     output_shapes=self._structure._flat_shapes, name=name)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_dataset_ops.py", line 1947, in iterator_get_next
#     output_shapes=output_shapes, name=name)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py", line 3616, in create_op
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py", line 2005, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
# pip show tensorflow
# Out:
# Name: tensorflow
# Version: 1.14.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: wheel, tensorflow-estimator, grpcio, numpy, termcolor, keras-applications, google-pasta, astor, protobuf, keras-preprocessing, six, absl-py, tensorboard, wrapt, gast
# Required-by: stable-baselines, magenta, fancyimpute
